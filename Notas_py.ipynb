# %% [markdown]
# <a href="https://colab.research.google.com/github/maurorpo/pythonbootcamp/blob/main/Notas_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro Bootcamp Python/Linux
#
# Recursos principales:
# 1. Repositorio: [GitHub](https://github.com/codingupmyfuture/bootcamplinuxpython)
# 2. [Presentación curso](contenido.curso/001.documentos/001.presentacion.curso.2023.pdf)

# %%
curso: str = 'Bootcamp.Python.linux'

# %% [markdown]
# ![68747470733a2f2f692e706f7374696d672e63632f467a7058513362742f636161702e6a7067.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Reglas de oro!
# * **Estandarización de textos:** Se recomienda setear/formatear los textos, en especial que todos se reciban como minúsculas o mayúsculas.
# * **Concatenacion de funciones:** puedo escribir varias funciones/metodos en una misma linea de código `curso.lower().center(20, '@').capitalize()`
#
# ### Sea curioso ###
# ### Miremos a ver que pasa si... ###

# %% [markdown]
# # Variables
#
# * Sintaxis recomendada `[nombre_variable_aqui]`
# * Evitar Hardcoding: No asignar el mismo valor en diferentes partes del proyecto, **usar variables de entorno**
# * Buena práctica: Variables de referencia. Agregar tipo de dato a la variable. Función no bloqueante. Ejemplo:  `edad: int = 27`
# * Casting, casteo, tipificar: cambiar tipo de variable, el dato debe de concordar con el nuevo tipo de variable
# ``` python
# tu_edad: str = '34'
# edad: int = int(tu_edad)
# ```

# %% [markdown]
# # Print
#
# * Print sep/end: se usa para agregar elementos a la hora de imprimir. `print(1,2,3,4, sep='0000', end='Finish') `

# %% [markdown]
# # Input
# * Permite pedir daots al usuario y guardarlos en una variable

# %% [markdown]
# # Slices
# **Permite iterar con strings, listas, duplas**
#
# * Acceder a elementos de un string o listas: `curso[1] , curso[5]`
# * Indispensable para iterar listas

# %%
print(curso[1])
print(curso[-5])
# Out:
# o
# l

# %% [markdown]
# # Rangos
# * Permite acceder a x rango dentro de una cadena, lista o tupla. `curso[2:4]`
# * Para revertir el orden de los elementos `curso[::-1]`
# * Imprimir hasta...: `curso[:10]`
# * Imprimir desde...: `curso[3:]`
# * Imprimir cada....: `curso[::2]`
#
# > El tercer dato es de brinco, cada x elementos imprime

# %% [markdown]
# # lower()
# Pasar el texto a minúsculas

# %% [markdown]
# # upper()
# Pasar el texto a mayúsculas

# %% [markdown]
# # startwith()
# Valida si el `string` empieza con x caracter `curso.startwith('x')` retorna booleano

# %% [markdown]
# # capitalize()
# Convierte el primer caracter en mayúscula

# %% [markdown]
# # title()
# Convierte en mayúscula el primer caracter de cada palabra

# %% [markdown]
# # center()
# Centra el texto y rellena los espacios. Recibe 2 parámetros, cantidad de caracters y valor a impirmir

# %%
print(curso.center( 50,'='))
# Out:
# ==============Bootcamp.Python.linux===============

# %% [markdown]
# # len()
# Devuelve el total de caracteres o valores:

# %%
curso: str = 'Bootcamp.Python.linux'
print(len(curso))
# Out:
# 21

# %% [markdown]
# # rjust()
# Agrega los caracteres filtrados al izquiero de la varialbe. Recibe 2 parámetros, la cantidad de carácteres a llenar (incluyendo el texto) y el caracter con el que se llenarán los espacios:

# %%
print(curso.rjust(50, '*'))
# Out:
# *****************************Bootcamp.Python.linux

# %% [markdown]
# # ljust()
# Agrega los caracteres filtrados al lado derecho del texto. Recibe 2 parámetros, la cantidad de carácteres a llenar (incluyendo el texto) y el caracter con el que se llenarán los espacios:

# %%
print(curso.ljust(50, '*'))
# Out:
# Bootcamp.Python.linux*****************************

# %% [markdown]
# # zfill()
# Agrega los caracteres filtrados al los lados del texto. Recibe 1 parámetro, la cantidad de espacio a formatear. Agrega `0` al formateo

# %%
print(curso.zfill(50))
# Out:
# 00000000000000000000000000000Bootcamp.Python.linux

# %% [markdown]
# # replace()
# Remplaza todos los elementos que encuentra por el nuevo. Recibe 2 parámetros, caracter que será cambiado y el nuevo valor.
# > Se recomienda siempre pasar el texto a minúsculas con `lower()` antes de reemplazar

# %%
print(curso.replace('o', '0'))
# Out:
# B00tcamp.Pyth0n.linux

# %% [markdown]
# # count()
# Retorna la cantidad de caracteres que encuentra. Recibe 1 parámetro, caracter a contar
# > Se recomienda siempre pasar el texto a minúsculas con `lower()` antes de reemplazar

# %%
print(curso.count('o'))
# Out:
# La letra "o" se repite 3 veces

# %% [markdown]
# # find()
# Encuentra y retorna la posición de la primera similutd del caracter buscado. Recibe 1 parámetro, caracter a buscar.
# Si retorna -1, es porque no encuentra similitud

# %%
print(curso.find('p'))
print(curso.find('z'))
# Out:
# 7
# -1

# %% [markdown]
# # lstrip()
# Formatea el texto al lado derecho.

# %%
espacios_derecha: str = '      Originalmente, tengo espacios a mi der'
print('Texto original: ', espacios_derecha)
print('Texto seteado: ', espacios_derecha.lstrip())
# Out:
# Texto original:        Originalmente, tengo espacios a mi der
# Texto seteado:  Originalmente, tengo espacios a mi der

# %% [markdown]
# #  rstrip()
# Formatea el texto al lado izq.

# %%
espacios_izq: str = 'Originalmente tengo espacios a mi izq         '
print('Texto original: ', espacios_izq)
print('Texto seteado : ', espacios_izq.rstrip())
# Out:
# Texto original:  Originalmente tengo espacios a mi izq
# Texto seteado :  Originalmente tengo espacios a mi izq

# %% [markdown]
# # strip()
# Formatea el texto a ambos lados.

# %%
espacio_ambos: str = '       Que desastre que se llene un formulario así        '
print('Texto original: ', espacio_ambos)
print('Texto seteado : ', espacio_ambos.strip())
# Out:
# Texto original:         Que desastre que se llene un formulario así
# Texto seteado :  Que desastre que se llene un formulario así

# %% [markdown]
# # index()
# Retorna la posición en la que se encuentra el elemento, !Pero! Si no la encuentra, tumba la aplicación

# %% [markdown]
# # split()
# Recibe 1 parámetro, el caracter que usará para separar/cortar el texto, retorna una lista

# %%
print(curso.split('.'))
# Out:
# ['Bootcamp', 'Python', 'linux']

# %% [markdown]
# # is...
# Función que valida si x se cumple, retorna bool

# %%
print(curso.islower())
print(curso.lower().islower())
# Out:
# False
# True

# %% [markdown]
# # Concatenar - Modo básico
# Para juntar 2 o mas elementos usamos el simbolo `+`

# %%
texto_1: str = 'Lo que'
texto_2: str = 'sea'
print( texto_1 + texto_2)
# Out:
# Lo quesea
